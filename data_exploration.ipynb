# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import seaborn as sb

# %%
df = pd.read_excel('Envelope Math.xlsx', sheetname='June')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 46 entries, (nan, Booked Profit, nan, 4216.33, nan, nan) to (nan, Profit, 2818.7, 2421, nan, nan)
# Data columns (total 14 columns):
# 1FF            5 non-null object
# Unnamed: 1     0 non-null float64
# Unnamed: 2     3 non-null float64
# Unnamed: 3     37 non-null object
# 2FF            40 non-null object
# Unnamed: 5     38 non-null object
# Unnamed: 6     36 non-null object
# Unnamed: 7     24 non-null float64
# Unnamed: 8     3 non-null object
# Unnamed: 9     0 non-null float64
# Unnamed: 10    2 non-null object
# Unnamed: 11    1 non-null float64
# Unnamed: 12    3 non-null float64
# Unnamed: 13    1 non-null float64
# dtypes: float64(7), object(7)
# memory usage: 5.4+ KB

# %%
df.head(50)
# Out:
#                                                                                                   1FF  \
# NaN Booked Profit    NaN          4216.33                  NaN            NaN               Occupancy
#     Potential Profit NaN          6238.78                  NaN            NaN    Average Nightly Rate
#     Date Adjustment  NaN          4393.78                  NaN            NaN    Implied Nightly Rate
#     NaN              NaN          NaN                      NaN            NaN                     NaN
#                                                                           NaN                     NaN
#                                                                           NaN                     NaN
#                                                                           NaN                     NaN
#     Southport 1FF    NaN          NaN                      NaN            NaN                     NaN
# ...
